# %% [markdown]
# ## Session 1:

# %%
#from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
#encoder = LabelEncoder()

# Fit and transform the categorical data
#encoded_labels = encoder.fit_transform(categorical_data)

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\sobia\Downloads\purchase-data.jpg.csv')

# %%
df.head(2)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['Gender']=encoder.fit_transform(df['Gender'])

# %%
df['Gender']

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/
#
# https://www.geeksforgeeks.org/python-pandas-get_dummies-method/
#
# https://www.statology.org/pandas-get-dummies/

# %% [markdown]
# ### get_dummys method

# %%
import pandas as pd
import numpy as np


# dictionary
diff = pd.DataFrame({'R': ['a', 'c', 'd'],
                    'T': ['d', 'a', 'c'],
                    'S_': [1, 2, 3]})

#print(pd.get_dummies(diff, prefix=['column1', 'column2']))

pd.get_dummies(diff)

# %% [markdown]
# ## Label Encoding

# %%
import pandas as pd

df1 = pd.DataFrame({'N': ['bakhtawar','rabia','Ramla'],
                   'T': ['d', 'a', 'c'],
                   'S_': [1, 2, 3]})

# %%
df1

# %%
df1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en = LabelEncoder()

# %%
df1['N']=en.fit_transform(df1['N'])

# %%
df1

# %% [markdown]
# ## one-hot encoding

# %% [markdown]
# ## Mobile Price Classification:

# %%
data = pd.read_csv(r'C:\Users\sobia\Downloads\archive (24)\train.csv')

# %%
data.shape

# %%
data.columns

# %%
data.head(3)

# %%
data['price_range'].unique()

# %%
data.describe()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=data['clock_speed'], y=data['price_range'])
plt.xticks(rotation="vertical")
plt.show()

# %%
data['battery_power'].value_counts().plot(kind='bar')

# %% [markdown]
# ## session 2:

# %% [markdown]
# https://www.w3resource.com/python-exercises/lambda/index.php

# %%
lambda arguments: expression

# %%
square = lambda x: x ** 2
print(square(5))  # Output: 25

# %%
square = lambda x: x ** 2
print(square(2))  # Output: 25

# %%
def add(x,y):
    
    return x+y


print(add(2,2)) #this is func call

add #this is reference

# %%
#event (condition)

lambda x,y:x+y

# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\sobia\Downloads\laptop_data.csv')

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# 1. add a column for a value 0 if it is not touch screen else 1

# %%
data['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#data[data['ScreenResolution']=='Touchscreen 1366x768']

# %%
data['Touchscreen']=data['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data['SSD']=data['Memory'].apply(lambda x: 1 if 'SSD' in x else 0)

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data['Touchscreen'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['SSD'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Touchscreen'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Touchscreen'>

# %%
data['Touchscreen']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1298    1
# 1299    1
# 1300    0
# 1301    0
# 1302    0
# Name: Touchscreen, Length: 1303, dtype: int64

# %%
data['Price']
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1303, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=data['Touchscreen'], y=data['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
data['IPS']=data['ScreenResolution'].apply(lambda x: 1 if "IPS" in x else 0)

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data['new']=data['ScreenResolution'].str.split("x")

# %%
data['new']
# Out:
# 0               [IPS Panel Retina Display 2560, 1600]
# 1                                         [1440, 900]
# 2                                [Full HD 1920, 1080]
# 3               [IPS Panel Retina Display 2880, 1800]
# 4               [IPS Panel Retina Display 2560, 1600]
#                             ...
# 1298     [IPS Panel Full HD / Touchscreen 1920, 1080]
# 1299    [IPS Panel Quad HD+ / Touchscreen 3200, 1800]
# 1300                                      [1366, 768]
# 1301                                      [1366, 768]
# 1302                                      [1366, 768]
# Name: new, Length: 1303, dtype: object

# %%
data['new'].apply(lambda)
# Out:
# 0               [IPS Panel Retina Display 2560, 1600]
# 1                                         [1440, 900]
# 2                                [Full HD 1920, 1080]
# 3               [IPS Panel Retina Display 2880, 1800]
# 4               [IPS Panel Retina Display 2560, 1600]
#                             ...
# 1298     [IPS Panel Full HD / Touchscreen 1920, 1080]
# 1299    [IPS Panel Quad HD+ / Touchscreen 3200, 1800]
# 1300                                      [1366, 768]
# 1301                                      [1366, 768]
# 1302                                      [1366, 768]
# Name: new, Length: 1303, dtype: object

# %%
data['new'].str.split('-',expand=True)
# Out:
#        0
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ...   ..
# 1298 NaN
# 1299 NaN
# 1300 NaN
# 1301 NaN
# 1302 NaN
#
# [1303 rows x 1 columns]

# %%
data['new'].str.split(pat=None, expand=False)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1298   NaN
# 1299   NaN
# 1300   NaN
# 1301   NaN
# 1302   NaN
# Name: new, Length: 1303, dtype: float64

# %%
data[['x_res', 'y_res']]= data['ScreenResolution'].str.extract(r'(\d+)x(\d+)') #regular expression

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
#data['ppsi']

type(data['x_res'])
# Out:
# pandas.core.series.Series

# %%
x_res*y_res/inches = ppsi

# %%
x=data['x_res'].astype('int')

# %%
y=data['x_res'].astype('int')

# %%
z=data['Inches']

# %%
data['ppsi']=x*y/z

# %%
data['ppsi']
# Out:
# 0       492751.879699
# 1       155909.774436
# 2       236307.692308
# 3       538597.402597
# 4       492751.879699
#             ...
# 1298    263314.285714
# 1299    769924.812030
# 1300    133282.571429
# 1301    119612.564103
# 1302    119612.564103
# Name: ppsi, Length: 1303, dtype: float64

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
sns.barplot(x = data['ppsi'])
# Out:
# <AxesSubplot:xlabel='ppsi'>

# %%
data['new_ppsi']=(data['x_res'])*(data['y_res'])/data['Inches']

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...
