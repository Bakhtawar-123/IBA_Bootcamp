# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\sobia\Downloads\pokemon.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                          image_url  Id  \
# 0           0  https://img.pokemondb.net/sprites/sword-shield...   1
# 1           1  https://img.pokemondb.net/sprites/sword-shield...   2
# 2           2  https://img.pokemondb.net/sprites/sword-shield...   3
# 3           3  https://img.pokemondb.net/sprites/sword-shield...   3
# 4           4  https://img.pokemondb.net/sprites/sword-shield...   4
#
#                     Names  Type1   Type2  Total  HP  Attack  Defense  Sp. Atk  \
# 0               Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                 Ivysaur  Grass  Poison    405  60      62       63       80
# 2                Venusaur  Grass  Poison    525  80      82       83      100
# 3  Venusaur Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4              Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed
# 0       65     45
# 1       80     60
# 2      100     80
# ...

# %%
df.shape
# Out:
# (1194, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1194 non-null   int64
#  1   image_url   1194 non-null   object
#  2   Id          1194 non-null   int64
#  3   Names       1194 non-null   object
#  4   Type1       1194 non-null   object
#  5   Type2       652 non-null    object
#  6   Total       1194 non-null   int64
#  7   HP          1194 non-null   int64
#  8   Attack      1194 non-null   int64
#  9   Defense     1194 non-null   int64
#  10  Sp. Atk     1194 non-null   int64
#  11  Sp. Def     1194 non-null   int64
#  12  Speed       1194 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 121.4+ KB

# %%
df["Type2"]
# Out:
# 0         Poison
# 1         Poison
# 2         Poison
# 3         Poison
# 4            NaN
#           ...
# 1189    Fighting
# 1190      Dragon
# 1191      Dragon
# 1192      Dragon
# 1193     Psychic
# Name: Type2, Length: 1194, dtype: object

# %%
df["Type2"].isnull().sum()
# Out:
# 542

# %%
df["Type2"].isna().sum()
# Out:
# 542

# %%
df[df['Type2'].isna()]`
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 4              4  https://img.pokemondb.net/sprites/sword-shield...    4
# 5              5  https://img.pokemondb.net/sprites/sword-shield...    5
# 9              9  https://img.pokemondb.net/sprites/sword-shield...    7
# 10            10  https://img.pokemondb.net/sprites/sword-shield...    8
# 11            11  https://img.pokemondb.net/sprites/sword-shield...    9
# ...          ...                                                ...  ...
# 1156        1156  https://img.pokemondb.net/sprites/scarlet-viol...  977
# 1163        1163  https://img.pokemondb.net/sprites/scarlet-viol...  982
# 1164        1164  https://img.pokemondb.net/sprites/scarlet-viol...  982
# 1181        1181  https://img.pokemondb.net/sprites/scarlet-viol...  999
# 1182        1182  https://img.pokemondb.net/sprites/scarlet-viol...  999
#
#                                Names   Type1 Type2  Total   HP  Attack  \
# ...

# %%
df
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
df.fillna('none', inplace=True)
# Out:
#   Input In [25]
#     df.fillna('none'), inplace=True
#     ^
# SyntaxError: cannot assign to function call

# %%
df['Speed']
# Out:
# 0        45
# 1        60
# 2        80
# 3        80
# 4        65
#        ...
# 1189    116
# 1190    135
# 1191    135
# 1192    109
# 1193    104
# Name: Speed, Length: 1194, dtype: int64

# %%
df['Speed']
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0        45
# 1        60
# 2        80
# 3        80
# 4        65
#        ...
# 1189    116
# 1190    135
# 1191    135
# 1192    109
# 1193    104
# Name: Speed, Length: 1194, dtype: int64>

# %%
df.describe()
# Out:
#         Unnamed: 0           Id        Total           HP       Attack  \
# count  1194.000000  1194.000000  1194.000000  1194.000000  1194.000000
# mean    596.500000   492.746231   441.206868    70.883585    80.948911
# std     344.822418   293.719541   121.015326    26.861740    32.126164
# min       0.000000     1.000000   175.000000     1.000000     5.000000
# 25%     298.250000   235.250000   330.000000    52.000000    56.000000
# 50%     596.500000   486.500000   460.500000    70.000000    80.000000
# 75%     894.750000   741.750000   520.000000    85.000000   100.000000
# max    1193.000000  1010.000000  1125.000000   255.000000   190.000000
#
#            Defense      Sp. Atk      Sp. Def        Speed
# count  1194.000000  1194.000000  1194.000000  1194.000000
# mean     74.587102    72.881072    72.123953    69.782245
# std      30.678626    32.702411    27.628412    30.200828
# min       5.000000    10.000000    20.000000     5.000000
# ...

# %%
df[df['Speed']>=200]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1063        1063  https://img.pokemondb.net/sprites/sword-shield...  894
#
#           Names     Type1 Type2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1063  Regieleki  Electric   NaN    580  80     100       50      100       50
#
#       Speed
# 1063    200

# %%
df['Speed'].describe()
# Out:
# count     True
# mean     False
# std      False
# min      False
# 25%      False
# 50%      False
# 75%      False
# max       True
# Name: Speed, dtype: bool

# %%
df[df['Speed'] == max(df['Speed'])]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1063        1063  https://img.pokemondb.net/sprites/sword-shield...  894
#
#           Names     Type1 Type2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1063  Regieleki  Electric   NaN    580  80     100       50      100       50
#
#       Speed
# 1063    200

# %%
df[df['Speed'] == min(df['Speed'])]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 272         272  https://img.pokemondb.net/sprites/sword-shield...  213
# 546         546  https://img.pokemondb.net/sprites/sword-shield...  446
# 928         928  https://img.pokemondb.net/sprites/sword-shield...  771
#
#          Names   Type1 Type2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 272    Shuckle     Bug  Rock    505   20      10      230       10      230
# 546   Munchlax  Normal   NaN    390  135      85       40       40       85
# 928  Pyukumuku   Water   NaN    410   55      60      130       30      130
#
#      Speed
# 272      5
# 546      5
# 928      5

# %%
# attack max type electric
#df[df['Sp. Atk'] == max(df['Sp. Atk'])]
df['Type1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Dark', 'Poison',
#        'Electric', 'Ground', 'Ice', 'Fairy', 'Steel', 'Fighting',
#        'Psychic', 'Rock', 'Ghost', 'Dragon', 'Flying'], dtype=object)

# %%
df[df['Type1']=='Electric'].max()
# Out:
# C:\Users\sobia\AppData\Local\Temp\ipykernel_33644\2197937913.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['Type1']=='Electric'].max()
# Unnamed: 0                                                 1191
# image_url     https://img.pokemondb.net/sprites/sword-shield...
# Id                                                         1008
# Names                                                   Zeraora
# Type1                                                  Electric
# Total                                                       670
# HP                                                          109
# Attack                                                      123
# Defense                                                     115
# Sp. Atk                                                     173
# ...

# %%
new_df=df[df['Type1']=='Electric']

# %%
new_df
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 32            32  https://img.pokemondb.net/sprites/sword-shield...    25
# 33            33  https://img.pokemondb.net/sprites/sword-shield...    25
# 34            34  https://img.pokemondb.net/sprites/sword-shield...    26
# 35            35  https://img.pokemondb.net/sprites/sword-shield...    26
# 110          110  https://img.pokemondb.net/sprites/sword-shield...    81
# ...          ...                                                ...   ...
# 1117        1117  https://img.pokemondb.net/sprites/scarlet-viol...   939
# 1118        1118  https://img.pokemondb.net/sprites/scarlet-viol...   940
# 1119        1119  https://img.pokemondb.net/sprites/scarlet-viol...   941
# 1171        1171  https://img.pokemondb.net/sprites/scarlet-viol...   989
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
#
#                         Names     Type1    Type2  Total   HP  Attack  Defense  \
# ...

# %%
new_df['Sp. Atk'].max()
# Out:
# 173

# %%
new_df['Attack'].max()
# Out:
# 123

# %%
# type is electric and find max value of attack
# two types  of sort in numeric acc and decending
# sort the catagorical data using dictionary
