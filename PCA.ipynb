# %%
from sklearn.decomposition import PCA

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\sobia\Downloads\pokemon.csv')

# %%
display(df.loc[(df["Type1"]== "Ice") & df['Names']])
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 37            37  https://img.pokemondb.net/sprites/sword-shield...   27
# 39            39  https://img.pokemondb.net/sprites/sword-shield...   28
# 49            49  https://img.pokemondb.net/sprites/sword-shield...   37
# 51            51  https://img.pokemondb.net/sprites/sword-shield...   38
# 162          162  https://img.pokemondb.net/sprites/sword-shield...  122
# 164          164  https://img.pokemondb.net/sprites/sword-shield...  124
# 191          191  https://img.pokemondb.net/sprites/sword-shield...  144
# 281          281  https://img.pokemondb.net/sprites/sword-shield...  220
# 282          282  https://img.pokemondb.net/sprites/sword-shield...  221
# 287          287  https://img.pokemondb.net/sprites/sword-shield...  225
# 301          301  https://img.pokemondb.net/sprites/sword-shield...  238
# 432          432  https://img.pokemondb.net/sprites/sword-shield...  351
# ...

# %%
display(df["Names"].loc[(df["Type1"]== "Ice") & df['Names']])
# Out:
# 37             Sandshrew Alolan Sandshrew
# 39             Sandslash Alolan Sandslash
# 49                   Vulpix Alolan Vulpix
# 51             Ninetales Alolan Ninetales
# 162            Mr. Mime Galarian Mr. Mime
# 164                                  Jynx
# 191                              Articuno
# 281                                Swinub
# 282                             Piloswine
# 287                              Delibird
# 301                              Smoochum
# 432                   Castform Snowy Form
# 444                               Snorunt
# 445                                Glalie
# 446                    Glalie Mega Glalie
# 447                                Spheal
# 448                                Sealeo
# 449                               Walrein
# 464                                Regice
# 573                               Glaceon
# 575                             Mamoswine
# 581                              Froslass
# ...

# %%
display(df["Type2"].loc[(df["Type1"]== "Flying") & df['Names']])
# Out:
# 767          NaN
# 768          NaN
# 859       Dragon
# 860       Dragon
# 982          NaN
# 983          NaN
# 984        Steel
# 1006       Water
# 1140        Dark
# 1152    Fighting
# Name: Type2, dtype: object

# %%
display(df["Names"].loc[(df["Type1"]== "Flying") & df['Names'] & df['Type2']])
# Out:
# 859          Noibat
# 860         Noivern
# 984     Corviknight
# 1006      Cramorant
# 1140     Bombirdier
# 1152        Flamigo
# Name: Names, dtype: object

# %%
#find names and speed where type1 is steel

display(df["Names"].loc[(df["Type1"]=="Steel") & df["Names"] & df["Type2"]])
# Out:
# 264                      Steelix
# 265         Steelix Mega Steelix
# 289                     Skarmory
# 374                       Mawile
# 375           Mawile Mega Mawile
# 376                         Aron
# 377                       Lairon
# 378                       Aggron
# 459                       Beldum
# 460                       Metang
# 461                    Metagross
# 462     Metagross Mega Metagross
# 476                      Jirachi
# 535                      Bronzor
# 536                     Bronzong
# 591                       Dialga
# 592          Dialga Origin Forme
# 764                     Cobalion
# 814                      Honedge
# 815                     Doublade
# 816       Aegislash Shield Forme
# 817        Aegislash Blade Forme
# 842      Sliggoo Hisuian Sliggoo
# 844        Goodra Hisuian Goodra
# 845                       Klefki
# 955                   Celesteela
# 962                     Magearna
# 1049                   Duraludon
# ...

# %%
df.loc[df['Type1']=="Ice"]['Names']
# Out:
# 37             Sandshrew Alolan Sandshrew
# 39             Sandslash Alolan Sandslash
# 49                   Vulpix Alolan Vulpix
# 51             Ninetales Alolan Ninetales
# 162            Mr. Mime Galarian Mr. Mime
# 164                                  Jynx
# 191                              Articuno
# 281                                Swinub
# 282                             Piloswine
# 287                              Delibird
# 301                              Smoochum
# 432                   Castform Snowy Form
# 444                               Snorunt
# 445                                Glalie
# 446                    Glalie Mega Glalie
# 447                                Spheal
# 448                                Sealeo
# 449                               Walrein
# 464                                Regice
# 573                               Glaceon
# 575                             Mamoswine
# 581                              Froslass
# ...

# %%
#Find only names of pokemons where type 1 is ice:

df.loc[(df["Type1"]=="Ice")]["Names"]
# Out:
# 37             Sandshrew Alolan Sandshrew
# 39             Sandslash Alolan Sandslash
# 49                   Vulpix Alolan Vulpix
# 51             Ninetales Alolan Ninetales
# 162            Mr. Mime Galarian Mr. Mime
# 164                                  Jynx
# 191                              Articuno
# 281                                Swinub
# 282                             Piloswine
# 287                              Delibird
# 301                              Smoochum
# 432                   Castform Snowy Form
# 444                               Snorunt
# 445                                Glalie
# 446                    Glalie Mega Glalie
# 447                                Spheal
# 448                                Sealeo
# 449                               Walrein
# 464                                Regice
# 573                               Glaceon
# 575                             Mamoswine
# 581                              Froslass
# ...

# %%
#tell a pokemon where defence and attack should be maximum

df["Names"].loc[(df["Defense"].max())&(df["Attack"].max())]
# Out:
# 'Kabuto'

# %%
#find names, type1, type2, where attack is max

df[["Names","Type1","Type2"]].loc[(df["Attack"].max())]
# Out:
# Names    Snorlax
# Type1     Normal
# Type2        NaN
# Name: 190, dtype: object

# %%
#find the rows where name start with G
df[df['Names'].str[0]=='G']
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 55            55  https://img.pokemondb.net/sprites/sword-shield...    42
# 57            57  https://img.pokemondb.net/sprites/sword-shield...    44
# 73            73  https://img.pokemondb.net/sprites/sword-shield...    55
# 76            76  https://img.pokemondb.net/sprites/sword-shield...    58
# 77            77  https://img.pokemondb.net/sprites/scarlet-viol...    58
# ...          ...                                                ...   ...
# 1150        1150  https://img.pokemondb.net/sprites/scarlet-viol...   971
# 1166        1166  https://img.pokemondb.net/sprites/scarlet-viol...   984
# 1181        1181  https://img.pokemondb.net/sprites/scarlet-viol...   999
# 1182        1182  https://img.pokemondb.net/sprites/scarlet-viol...   999
# 1183        1183  https://img.pokemondb.net/sprites/scarlet-viol...  1000
#
#                             Names   Type1     Type2  Total   HP  Attack  \
# ...

# %%
#Find the rows where defense is between 5 and 14

df.loc[(df['Defense']>5)&(df['Defense']<14)]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 305         305  https://img.pokemondb.net/sprites/sword-shield...  242
#
#        Names   Type1 Type2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 305  Blissey  Normal   NaN    540  255      10       10       75      135
#
#      Speed
# 305     55

# %%
df=pd.read_csv(r'C:\Users\sobia\Downloads\laptop_data.csv')

# %%
df['Ram']=df['Ram'].str.replace('GB','')

# %%
df['Ram']=df['Ram'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int32(1), int64(1), object(8)
# memory usage: 117.2+ KB

# %%
df['ScreenResolution'] lambda x: Touchscreen
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', 'Touchscreen 2560x1440',
#        '1600x900', 'IPS Panel 4K Ultra HD 3840x2160',
#        '4K Ultra HD 3840x2160', 'Touchscreen 1366x768',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df['new']=df['ScreenResolution'].str.split("x")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
#find the rows where cpu contain core i5 and type ultrabook
df.loc[(df['Cpu']=='Corei5')& df['TypeName']=='Ultrabook']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price, Touchscreen, new]
# Index: []

# %%
#df.loc[df['Cpu'].apply(lambda x:'Core i5' in x ) & df['TypeName'].apply(lambda x:'Ultrabook' in x )]

# %%
df.loc[df['Cpu'].apply(lambda x: 'Core i5' in x)& df['TypeName'].apply(lambda x: 'Ultrabook' in x)]
# Out:
#       Unnamed: 0 Company   TypeName  Inches  \
# 0              0   Apple  Ultrabook    13.3
# 1              1   Apple  Ultrabook    13.3
# 4              4   Apple  Ultrabook    13.3
# 7              7   Apple  Ultrabook    13.3
# 9              9    Acer  Ultrabook    14.0
# ...          ...     ...        ...     ...
# 1105        1105    Dell  Ultrabook    12.5
# 1127        1127      HP  Ultrabook    12.5
# 1188        1188    Dell  Ultrabook    13.3
# 1223        1223    Dell  Ultrabook    12.5
# 1234        1234   Apple  Ultrabook    11.6
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                               1440x900        Intel Core i5 1.8GHz    8
# 4     IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
# 7                               1440x900        Intel Core i5 1.8GHz    8
# ...

# %%
#find the rows GPU contain intel and company is asu and prices is min

df.loc[df['Gpu'].apply(lambda x : 'Intel' in x)& df['Company'].apply(lambda x: 'Asu' in x)]
# Out:
#       Unnamed: 0 Company   TypeName  Inches             ScreenResolution  \
# 20            20    Asus    Netbook    11.6                     1366x768
# 40            40    Asus   Notebook    15.6            Full HD 1920x1080
# 57            57    Asus   Notebook    15.6                     1366x768
# 59            59    Asus   Notebook    15.6            Full HD 1920x1080
# 63            63    Asus   Notebook    14.0            Full HD 1920x1080
# ...          ...     ...        ...     ...                          ...
# 1274        1274    Asus   Notebook    15.6                     1366x768
# 1275        1275    Asus  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 1288        1288    Asus   Notebook    15.6                     1366x768
# 1289        1289    Asus  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 1302        1302    Asus   Notebook    15.6                     1366x768
#
#                                        Cpu  Ram              Memory  \
# ...

# %%
#find the rows where ram is 8 gb also visulize the price 
df[df['Ram']==8]
# Out:
#       Unnamed: 0 Company   TypeName  Inches  \
# 0              0   Apple  Ultrabook    13.3
# 1              1   Apple  Ultrabook    13.3
# 2              2      HP   Notebook    15.6
# 4              4   Apple  Ultrabook    13.3
# 7              7   Apple  Ultrabook    13.3
# ...          ...     ...        ...     ...
# 1279        1279  Lenovo   Notebook    15.6
# 1281        1281    Dell   Notebook    15.6
# 1289        1289    Asus  Ultrabook    13.3
# 1293        1293  Lenovo   Notebook    15.6
# 1295        1295    Dell   Notebook    15.6
#
#                         ScreenResolution                          Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz    8
# 1                               1440x900         Intel Core i5 1.8GHz    8
# 2                      Full HD 1920x1080   Intel Core i5 7200U 2.5GHz    8
# 4     IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz    8
# ...

# %%
df['new_weight']=df['Weight'].str.split('Kg','' )

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df['new_weight'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 df['new_weight'].astype('int')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
# ...

# %%
#find the rows where weight is greater than 8 and less than 16.

df.loc[(df['Ram']>8) & (df['Ram']<16)]
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 44            44    Dell  2 in 1 Convertible    17.3
# 69            69    Asus              Gaming    17.3
# 99            99      HP              Gaming    15.6
# 275          275    Dell            Notebook    15.6
# 285          285    Acer            Notebook    15.6
# 341          341  Lenovo            Notebook    15.6
# 370          370    Asus  2 in 1 Convertible    15.6
# 392          392    Acer            Notebook    15.6
# 428          428      HP              Gaming    17.3
# 468          468      HP              Gaming    17.3
# 469          469  Lenovo           Ultrabook    14.0
# 474          474    Asus            Notebook    15.6
# 538          538      HP              Gaming    17.3
# 587          587  Lenovo           Ultrabook    14.0
# 588          588  Lenovo            Notebook    15.6
# 591          591  Lenovo            Notebook    15.6
# 731          731    Dell            Notebook    15.6
# ...
