# %% [markdown]
# # Sequential Neural Network
#
# https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/

# %%
import pandas as pd

# %%
nba = pd.read_csv(r'C:\Users\sobia\Downloads\nba.csv')

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
diabetes  = pd.read_csv(r'C:\Users\sobia\Downloads\archive (33)\diabetes.csv')

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
y = diabetes['Outcome']

# %%
 diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
feature_columns = [0,1,2,3,4,5,6,7] 
x =  diabetes.iloc[:,feature_columns ]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=0.30, random_state=0)

# %%
# first neural network with keras tutorial
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


# define the keras model
model = Sequential()
#input layer
model.add(Dense(12, input_dim=8, activation='relu'))
#hidden layer
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
#output layer
model.add(Dense(1, activation='sigmoid'))
# for multi class use accordingly dense layer and samo function we use

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 12)                108
#
#  dense_8 (Dense)             (None, 8)                 104
#
#  dense_9 (Dense)             (None, 4)                 36
#
#  dense_10 (Dense)            (None, 1)                 5
#
# ...
# Total params: 253
# Trainable params: 253
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#adam is advaptive func set learning rat

# %%
# fit the keras model on the dataset
model.fit(xtrain, ytrain, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4784 - accuracy: 0.7579
# Epoch 2/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4741 - accuracy: 0.7579
# Epoch 3/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4791 - accuracy: 0.7542
# Epoch 4/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7523
# Epoch 5/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4690 - accuracy: 0.7747
# Epoch 6/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.7561
# Epoch 7/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4901 - accuracy: 0.7523
# Epoch 8/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4757 - accuracy: 0.7616
# Epoch 9/150
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.7598
# Epoch 10/150
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4574 - accuracy: 0.7734
# Accuracy: 77.34

# %%
# evaluate the keras model
_, accuracy = model.evaluate(x, y, verbose=0)

# %% [markdown]
# ## Make Predictions
