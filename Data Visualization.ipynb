# %%
import pandas as pd

# %%
df= pd.read_excel(r'C:\Users\sobia\Downloads\supermarket_sales.xlsx')

# %%
df
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    692-92-5582      B  Mandalay        Member  Female
# 1    351-62-0822      B  Mandalay        Member  Female
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 4    319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 995  886-18-2897      A    Yangon        Normal  Female
# 996  745-74-0715      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total  \
# 0        Food_and_beverages       54.84         3   8.226  172.746
# 1       Fashion_accessories       14.48         4   2.896   60.816
# 2    Electronic_accessories       25.51         4   5.102  107.142
# ...

# %%
df['Tax 5%'].sum()
# Out:
# 15379.369

# %%
df['Total'].sum()
# Out:
# 322966.749

# %%
df['Total'].median()
# Out:
# 253.848

# %%
R=df['Rating'].max()

# %%
df.groupby(['Gender','Payment']).count()
# Out:
#                     Invoice ID  Branch  City  Customer type  Product line  \
# Gender Payment
# Female Cash                178     178   178            178           178
#        Credit card         163     163   163            163           163
#        Ewallet             160     160   160            160           160
# Male   Cash                166     166   166            166           166
#        Credit card         148     148   148            148           148
#        Ewallet             185     185   185            185           185
#
#                     Unit price  Quantity  Tax 5%  Total  Date  Time  cogs  \
# Gender Payment
# Female Cash                178       178     178    178   178   178   178
#        Credit card         163       163     163    163   163   163   163
#        Ewallet             160       160     160    160   160   160   160
# Male   Cash                166       166     166    166   166   166   166
# ...

# %%
df.groupby(['Gender','Payment']).count()['Quantity']
# Out:
# Gender  Payment
# Female  Cash           178
#         Credit card    163
#         Ewallet        160
# Male    Cash           166
#         Credit card    148
#         Ewallet        185
# Name: Quantity, dtype: int64

# %%
#groupby branch, city, customer type

df.groupby(['City','Branch'])

# %%
df.groupby(['Customer type','Gender']).count()['Product line']
# Out:
# Customer type  Gender
# Member         Female    261
#                Male      240
# Normal         Female    240
#                Male      259
# Name: Product line, dtype: int64

# %%
df['Product line'].unique()
# Out:
# array(['Food_and_beverages', 'Fashion_accessories',
#        'Electronic_accessories', 'Sports_and_travel',
#        'Home_and_lifestyle', 'Health_and_beauty'], dtype=object)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 17)

# %%
df['City'].unique()
# Out:
# array(['Mandalay', 'Naypyitaw', 'Yangon'], dtype=object)

# %%
#find the payment types in dataset
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
#find the rows where payment is cash
df['Payment'].unique()
# Out:
# array(['Credit card', 'Ewallet', 'Cash'], dtype=object)

# %%
df[df['Payment']=='Cash']
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 7    649-29-6775      B  Mandalay        Normal    Male
# 8    145-94-9061      B  Mandalay        Normal  Female
# 10   149-71-6266      B  Mandalay        Member    Male
# ..           ...    ...       ...           ...     ...
# 992  221-25-5073      A    Yangon        Normal  Female
# 993  809-46-1866      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2    Electronic_accessories       25.51         4   5.1020  107.1420
# 3         Sports_and_travel       93.72         6  28.1160  590.4360
# 7       Fashion_accessories       33.52         1   1.6760   35.1960
# ...

# %%
#how many cities in dataset
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
#find out customer type in dataset 
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Customer type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
#find the braches in dataset
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
#find out the mode of ratting in data set where branch is B
b=df[df['Branch']=='B']
b['Rating'].mode()
# Out:
# 0    5.1
# 1    6.5
# 2    8.9
# Name: Rating, dtype: float64

# %%
#find the rows where gender is male and customer 

df['Gender']=='Male'
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Customer type'] == "Member"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Customer type, Length: 1000, dtype: bool

# %%
df.loc[(df['Gender']=='Male') & (df['Customer type'] == "Member")]
# Out:
#       Invoice ID Branch      City Customer type Gender  \
# 2    529-56-3974      B  Mandalay        Member   Male
# 10   149-71-6266      B  Mandalay        Member   Male
# 12   777-82-7220      B  Mandalay        Member   Male
# 16   370-41-7321      B  Mandalay        Member   Male
# 18   669-54-1719      B  Mandalay        Member   Male
# ..           ...    ...       ...           ...    ...
# 972  522-57-8364      A    Yangon        Member   Male
# 982  333-23-2632      A    Yangon        Member   Male
# 986  324-92-3863      A    Yangon        Member   Male
# 989  195-06-0432      A    Yangon        Member   Male
# 997  727-02-1313      A    Yangon        Member   Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2    Electronic_accessories       25.51         4   5.1020  107.1420
# 10        Sports_and_travel       78.07         9  35.1315  737.7615
# 12       Home_and_lifestyle       30.12         8  12.0480  253.0080
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.groupby(['Gender', 'Payment']).agg(['count', 'sum','min', 'max'])['Quantity']
# Out:
# C:\Users\sobia\AppData\Local\Temp\ipykernel_27484\769354623.py:1: FutureWarning: ['Date', 'Time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['Gender', 'Payment']).agg(['count', 'sum','min', 'max'])['Quantity']
#                     count   sum  min  max
# Gender Payment
# Female Cash           178  1004    1   10
#        Credit card    163   928    1   10
#        Ewallet        160   937    1   10
# Male   Cash           166   892    1   10
#        Credit card    148   794    1   10
#        Ewallet        185   955    1   10

# %%
df.groupby(['Gender', 'Product line']).agg(['count', 'sum','min', 'max'])['Payment']
# Out:
# C:\Users\sobia\AppData\Local\Temp\ipykernel_27484\3817159704.py:1: FutureWarning: ['Date', 'Time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['Gender', 'Product line']).agg(['count', 'sum','min', 'max'])['Payment']
#                                count  \
# Gender Product line
# Female Electronic_accessories     84
#        Fashion_accessories        96
#        Food_and_beverages         90
#        Health_and_beauty          64
#        Home_and_lifestyle         79
#        Sports_and_travel          88
# Male   Electronic_accessories     86
#        Fashion_accessories        82
#        Food_and_beverages         84
#        Health_and_beauty          88
#        Home_and_lifestyle         81
#        Sports_and_travel          78
#
#                                                                              sum  \
# Gender Product line
# ...

# %% [markdown]
# ## home work
#
# date time index
#
# index = 0 ,1
#
# ### make date time into index
#
# ### types of graphs

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.set_index(df['Date'], drop=False, append=False, inplace=False, verify_integrity=False).drop('Date', 1)
# Out:
# C:\Users\sobia\AppData\Local\Temp\ipykernel_27484\1062361737.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.set_index(df['Date'], drop=False, append=False, inplace=False, verify_integrity=False).drop('Date', 1)
#                       Invoice ID Branch      City Customer type  Gender  \
# Date
# 2/20/2019            692-92-5582      B  Mandalay        Member  Female
# 2019-06-02 00:00:00  351-62-0822      B  Mandalay        Member  Female
# 2019-09-03 00:00:00  529-56-3974      B  Mandalay        Member    Male
# 1/15/2019            299-46-1805      B  Mandalay        Member  Female
# 2019-11-03 00:00:00  319-50-3348      B  Mandalay        Normal  Female
# ...                          ...    ...       ...           ...     ...
# 3/22/2019            886-18-2897      A    Yangon        Normal  Female
# 2019-10-03 00:00:00  745-74-0715      A    Yangon        Normal    Male
# ...

# %% [markdown]
# ## Types of graphs :
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x='Gender' , data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,5))
sns.countplot(x = 'Product line', data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize = (15,5))
sns.countplot(x = 'Product line', data=df, hue = "Gender")
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.countplot(x='Payment', data=df, hue='Gender' )
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x='Payment', data=df, hue='Gender', palette = 'PuBuGn_r' )
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x='Payment', data=df, hue='Gender', facecolor=(0,0,0,0), linewidth=5, edgecolor=sns.color_palette('dark',3))
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
plt.figure(figsize = (15,5))
sns.countplot(x = 'Product line', data=df, facecolor=(0,0,0,0), linewidth=5, edgecolor=sns.color_palette('dark',3))
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x='Product line', y='Total', data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
df['Customer type']
# Out:
# 0      Member
# 1      Member
# 2      Member
# 3      Member
# 4      Normal
#         ...
# 995    Normal
# 996    Normal
# 997    Member
# 998    Normal
# 999    Member
# Name: Customer type, Length: 1000, dtype: object

# %% [markdown]
# ### draw a bar graph for customer type and rating and hue is gender

# %%
sns.barplot(x='Customer type', y='Rating', data=df, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='Rating'>

# %% [markdown]
# ### draw bar graph for gender and quantity and hue is payment

# %%
sns.barplot(x ='Gender', y ='Quantity',data=df, hue ='Payment')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Quantity'>

# %% [markdown]
# ### draw a bar graph for branch and total and hue is payment

# %%
sns.barplot(x = 'Branch', y= 'Total',data=df, hue = 'Payment')
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x='Product line', y='Total', data=df, order = ['Electronic_accessories', 'Fashion_accessories', 'Food_and_beverages','Sports_and_travel','Home_and_lifestyle','Health_and_beauty'],hue='Gender', hue_order=["Male","Female"])
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x='Product line', y='Total',data=df,hue='Payment', hue_order=['Ewallet', 'Cash','Credit card'])
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
df['Payment'].unique()
# Out:
# array(['Credit card', 'Ewallet', 'Cash'], dtype=object)

# %%
sns.boxplot(y='Total', data=df, width = 0.2, showmeans = True)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.boxplot(y='Total', data=df, width = 0.2, showmeans = True, meanprops = {'marker':'o', 'markerfacecolor':'white', 'markersize':10, 'markeredgecolor':'black'})
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.boxplot(y='cogs', data=df, width = 0.2, showmeans = True)
# Out:
# <AxesSubplot:ylabel='cogs'>

# %%
sns.boxplot(x = 'Payment', y='Total', data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.boxplot(x = 'Payment', y='Total', hue = 'Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize = (15,5))
sns.boxplot(x = 'Product line', y='Rating', hue = 'Payment', data=df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Rating'>

# %% [markdown]
#   # home work
#   ### bot gig

# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\sobia\Downloads\supermarket_sales.xlsx')

# %%
#vilont plot
#kernal destinay

# %% [markdown]
# ### kernal density ? or spread

# %%
import seaborn as sns

# %%
sns.violinplot('Total', data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', hue='Gender', data=df, split=2)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', hue='Gender', data=df, split=2, inner='quartile')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', hue='Gender', data=df, split=2, inner='quartile')
sns.boxplot(x='Payment',y='Total', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
#to find density 
sns.stripplot(data=df, y='Total')
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.stripplot(data=df,x='Payment', y='Total')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(data=df,x='Payment', y='Total', hue='Gender')
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.stripplot(data=df,x='Product line', y='Total', hue='Customer type')
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.stripplot(data=df,x='Product line', y='Total', hue='Customer type', dodge=True)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.stripplot(data=df,x='Product line', y='Total', hue='Customer type', dodge=True, jitter=0.2)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.stripplot(data=df,x='Product line', y='Total', hue='Customer type', dodge=True, jitter=0.2, linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.stripplot(data=df,x='Product line', y='Total', hue='Customer type', dodge=True, jitter=0.2)
sns.boxplot(data=df,x='Product line', y='Total', hue='Customer type')
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='Total'>

# %%
import pandas as pd

# %%
df= pd.read_excel(r'C:\Users\sobia\Downloads\supermarket_sales.xlsx')

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
import seaborn as sns
sns.histplot(x = 'Total', data = df)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(y = 'Total', data =df)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Total'>

# %%
sns.histplot(x = 'Total', data = df, binwidth = 100)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
#hist plot for value and percantage 
# unit price draw hist plot width is 20

sns.histplot(x = 'Unit price', data =df,  binwidth = 20)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='Count'>

# %%
sns.histplot(x = 'Unit price', data =df,  kde = 2)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='Count'>

# %%
sns.histplot(x = 'Total', data = df, binwidth = 100, kde = 2)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(x = 'Total', data = df, hue = 'Payment')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(x = 'Total', data = df, hue = 'Payment', multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(x = 'Total', data = df, hue = 'Payment', element = 'poly', binwidth = 50)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(x = 'Total', data = df, hue = 'Payment',  binwidth = 50, stat = 'probability')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Probability'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.histplot(x = 'Total', y = 'gross income', data = df)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='gross income'>

# %%
#draw a hist for total and rating

# %%
sns.histplot(x = 'Rating', data=df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.histplot(y = 'Total', x = 'Rating', data=df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Total'>

# %%
#draw a hist for total and product line where hue is branch is B

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 5))

b_branch = df.loc[(df['Branch']=='B')]

sns.histplot(y ='Total', x= 'Product line', data=b_branch, cmap='coolwarm')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#draw a hist for total and customer types where payment is cash

# %%
sns.histplot(y= 'Total', x='Customer type', data=df)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='Total'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
filter = df[df['Payment'] == 'Cash']
sns.histplot(data = filter, x = "Total", hue = "Customer type", bins=12)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.histplot(data = filter, x = "Total", bins=12)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Count'>

# %%
sns.kdeplot(x = 'Total', data=df)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#find kde for unit price for normal and member

sns.kdeplot(x = 'Unit price', hue = 'Customer type', data =df)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='Density'>

# %%
#find KDE for total with respect to payment 
sns.kdeplot(x='Total', data=df, hue  = 'Payment')
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %%
#find kde rating with respect to gender

sns.kdeplot(x = 'Rating', hue= 'Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
# find the KDE for quantity with respect to gender

sns.kdeplot(x = 'Quantity', hue = 'Gender', data=df, multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Density'>

# %%
# find the KDE for tax with respect to gender

sns.kdeplot(x = 'Tax 5%', hue = 'Gender', data=df, multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='Tax 5%', ylabel='Density'>

# %%
import pandas as pd

# %%
df= pd.read_excel(r'C:\Users\sobia\Downloads\supermarket_sales.xlsx')

# %%
df.head(2)
# Out:
#     Invoice ID Branch      City Customer type  Gender         Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female   Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female  Fashion_accessories
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0  Credit card  164.52                 4.761905         8.226     5.9
# 1      Ewallet   57.92                 4.761905         2.896     4.5

# %%
import numpy as np

# %%
#generate random numerbs from 1 to 51
x = np.random.randint(1,51,50)
x
# Out:
# array([11, 16, 49, 43, 28, 13, 12, 19, 10, 33,  7,  7, 40, 22, 48, 29, 26,
#         4, 46, 49, 50,  1, 35,  4, 25,  2, 38, 22, 33, 37, 34, 12,  6, 40,
#         9, 45,  9, 28, 18, 32, 22, 12,  3, 39, 31, 11, 23, 13, 40, 45])

# %%
y = np.random.randint(1,51,50)
y
# Out:
# array([10,  3,  2, 30, 15, 11, 23, 39, 32, 41, 13, 31,  3,  7, 44, 22, 36,
#        50, 26, 37, 40,  1, 24, 50, 44, 11, 28, 36, 16, 30, 32, 48, 16, 34,
#        49, 30,  9,  9, 27, 48, 35, 39, 34, 36, 16,  7, 33,  9, 44,  9])

# %%
z = np.random.randint(1,51,50)
z
# Out:
# array([22, 39, 37,  4, 44, 15,  9, 49, 33, 43, 30, 33, 23,  1, 18, 24, 16,
#        47,  2,  7,  8,  1, 30,  7, 22,  8,  5, 49, 39, 44, 38, 41,  5, 15,
#         6,  2,  5, 35, 39, 16, 26, 20, 10, 33, 39,  7, 50, 28, 25, 15])

# %%
import matplotlib.pyplot as plt

x = np.random.randint(1,51,50)
y = np.random.randint(1,51,50)
z = np.random.randint(1,51,50)
plt.plot(x)
plt.plot(y)

# %%
import seaborn as sns
x = np.random.randint(1,51,50)
y = np.random.randint(1,51,50)
z = np.random.randint(1,51,50)
sns.set_style('darkgrid')
plt.plot(x)
plt.plot(y)

# %%
plt.figure (figsize =(15,8))
axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)
axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
plt.figure (figsize =(15,8))
axes = plt.axes(projection ="3d")
axes.scatter3D(10,10,10)
axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#visualize graph margin % with respect to product line

# %%
#visualize unit price in line plot

# %%
#visuliza unit price with respect to male and female

# %%
#pip install tensorflow opencv-python

# %%
#draw a 3d graph for object to point values for randomly generated arrays
#x contains 10 random numbers b/w 10 to 30
#y contains 10 random numbers b/w 5 to 15
#z contains 10 random 12 to 26

# %%
import numpy as np
x = np.random.randint(10,30,10)
y = np.random.randint(5, 15, 10)
z = np.random.randint(12, 26, 10)

# %%
x,y,z
# Out:
# (array([21, 23, 10, 15, 17, 29, 22, 27, 29, 22]),
#  array([14,  8, 13, 10,  7, 10, 12, 11, 11,  6]),
#  array([22, 24, 24, 21, 17, 25, 15, 12, 23, 23]))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
#use to see angles
#axes.view_init(42,215)

# 0 == 360 angle between 360 do not use 360 where 0 is equal to 360

# %%
plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.view_init(42,215)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
#try 0,45,90,180,270

# %%
plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.view_init(0,215)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.view_init(45,215)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.view_init(90,215)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.view_init(45,90)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %%
plt.figure (figsize =(15,8))

axes = plt.axes(projection ="3d")
axes.scatter3D(x,y,z)

axes.view_init(0,270)

axes.set_xlabel = ("x axis")
axes.set_ylabel = ("y axis")
axes.set_zlabel = ("z axis")
plt.show()

# %% [markdown]
# # Trignrometry

# %%
np.cos(10)
# Out:
# -0.8390715290764524

# %%
np.sin(10)
# Out:
# -0.5440211108893698

# %%
np.tan(10)
# Out:
# 0.6483608274590866

# %%
z1=np.linspace(0,10,100)

# %%
z1
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
#z1[50]

# %%
OMEGA = 2
x1 = np.cos(OMEGA*z1)

# %%
y1 = np.sin(OMEGA*z1)

# %%
x1, y1,z1
# Out:
# (array([ 1.        ,  0.97966323,  0.91948007,  0.8218984 ,  0.69088721,
#          0.53177518,  0.35103397,  0.15601496, -0.04534973, -0.24486989,
#         -0.43443032, -0.60632092, -0.75355031, -0.87013012, -0.95131866,
#         -0.9938137 , -0.9958868 , -0.95745366, -0.88007748, -0.76690542,
#         -0.6225406 , -0.45285485, -0.26474988, -0.06587659,  0.13567613,
#          0.33171042,  0.51425287,  0.67587883,  0.8100144 ,  0.91120382,
#          0.97533134,  0.99978867,  0.98358105,  0.9273677 ,  0.83343502,
#          0.70560358,  0.54907273,  0.37020915,  0.17628785, -0.0248037 ,
#         -0.2248864 , -0.41582217, -0.58984498, -0.7398767 , -0.859815  ,
#         -0.94478159, -0.99132055, -0.99753899, -0.96318398, -0.88965286,
#         -0.7799364 , -0.63849716, -0.47108797, -0.28451797, -0.08637561,
#          0.11527995,  0.31224667,  0.4965132 ,  0.66058479,  0.79778804,
#          0.90254243,  0.97058721,  0.99915477,  0.98708316,  0.93486337,
# ...

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize = (10,8))

axes=plt.axes(projection = '3d')

axes.plot3D(x1,y1,z1)

plt.show()

# %%
plt.figure(figsize = (10,8))

axes=plt.axes(projection = '3d')

axes.plot3D(x1,y1,z1,lw=3)

plt.show()

# %%
plt.figure(figsize = (10,8))

axes=plt.axes(projection = '3d')

axes.plot3D(x1,y1,z1,lw=3)

axes.view_init(90,241)

plt.show()

# %%
#3d scatter any data 
#google search for 3d plot
#3d plot 
#3d surface plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate random 3D data
np.random.seed(0)
n_points = 100
x = np.random.rand(n_points)
y = np.random.rand(n_points)
z = np.random.rand(n_points)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the data points
ax.scatter(x, y, z, c='b', marker='o')

# Set labels for each axis
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Set the title of the plot
ax.set_title('3D Scatter Plot')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Define the function that generates the z values (height of the surface)
z = np.sin(np.sqrt(x**2 + y**2))

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(x, y, z, cmap='viridis')

# Add color bar
fig.colorbar(surf)

# Set axis labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# Show the plot
plt.show()
